# %%
import matplotlib.pyplot as plt
import pandas as pd
from wordcloud import WordCloud

# %% [markdown]
# # چه کلماتی در نظرات بیشتر از همه ظاهر شده‌اند؟

# %%
df4 = pd.read_excel('4.xlsx')

# %%
comments = df4['comment']
comments.to_csv('cms.txt', index=False)

# %%
text = open("cms.txt", encoding="utf-8").read()

# %%
wordcloud = WordCloud(font_path='nazanin.ttf').generate(text)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# from persian_wordcloud.wordcloud import PersianWordCloud
# wordcloud = PersianWordCloud(only_persian=True).generate(text)
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-99a9ec88eb59> in <module>
#       1 from persian_wordcloud.wordcloud import PersianWordCloud
# ----> 2 wordcloud = PersianWordCloud(only_persian=True).generate(text)
#       3 plt.imshow(wordcloud, interpolation='bilinear')
#       4 plt.axis("off")
#
# /usr/local/lib/python3.7/site-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     142         """
#     143         # reshape persian words
# --> 144         text = get_display(arabic_reshaper.reshape(text))
#     145         return self.generate_from_text(text)
#     146
#
# /usr/local/lib/python3.7/site-packages/bidi/algorithm.py in get_display(unicode_or_str, encoding, upper_is_rtl, base_dir, debug)
#     646     resolve_weak_types(storage, debug)
#     647     resolve_neutral_types(storage, debug)
# ...

# %%
! pip install python-bidi
# Out:
# ...
# You are using pip version 19.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
! pip install arabic_reshaper
# Out:
# ...
# You are using pip version 19.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from bidi.algorithm import get_display
import arabic_reshaper

# %%
reshaped_text = arabic_reshaper.reshape(text)
persian_text = get_display(reshaped_text)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-a59ad02c257b> in <module>
#       1 reshaped_text = arabic_reshaper.reshape(text)
# ----> 2 persian_text = get_display(reshaped_text)
#
# /usr/local/lib/python3.7/site-packages/bidi/algorithm.py in get_display(unicode_or_str, encoding, upper_is_rtl, base_dir, debug)
#     646     resolve_weak_types(storage, debug)
#     647     resolve_neutral_types(storage, debug)
# --> 648     resolve_implicit_levels(storage, debug)
#     649     reorder_resolved_levels(storage, debug)
#     650     apply_mirroring(storage, debug)
#
# /usr/local/lib/python3.7/site-packages/bidi/algorithm.py in resolve_implicit_levels(storage, debug)
#     464             # only those types are allowed at this stage
#     465             assert _ch['type'] in ('L', 'R', 'EN', 'AN'),\
# ...

# %%
wordcloud = WordCloud(font_path='nazanin.ttf').generate(persian_text)
