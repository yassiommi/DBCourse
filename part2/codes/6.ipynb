# %%
import pandas as pd

# %% [markdown]
# # تحلیل کنید که در چه دسته‌هایی از محصولات، محصولاتی با برند متفرقه بیش‌تر فروش رفته‌اند. آیا به قیمت آن‌ها ربطی دارد؟

# %%
df3 = pd.read_csv('3.csv')

# %%
df5 = pd.read_excel('5.xlsx')

# %%
df5.head()
# Out:
#        id                                   product_title_fa  \
# 0  723302            ماگ حرارتی لومانا مدل عرفانه کد MAG1042
# 1  727089       ست آبکش و آبگیر تیتیز مدل AP-9141 سایز متوسط
# 2  727096  روغن مرطوب کننده کدلی مدل Divine oil حجم 50 می...
# 3  727803  ست لحاف پوپلین هوبی مدل اما یکنفره چهار تکه کاوری
# 4  725222                         ماگ آبنبات رنگی مدل AR0143
#
#                          product_title_en  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3  Hobby Emma Quilt Single Set - 4 Pieces
# 4                                     NaN
#
#                                             url_code  \
# 0            ماگ-حرارتی-لومانا-مدل-عرفانه-کد-mag1042
# 1       ست-آبکش-و-آبگیر-تیتیز-مدل-ap-9141-سایز-متوسط
# 2  روغن-مرطوب-کننده-کدلی-مدل-divine-oil-حجم-50-می...
# 3  ست-لحاف-پوپلین-هوبی-مدل-اما-یکنفره-چهار-تکه-کاوری
# 4                         ماگ-آبنبات-رنگی-مدل-ar0143
#
# ...

# %%
df3.head()
# Out:
#    ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 0   2714054       469662    21386  2015-10-15 08:50:56.000
# 1  11104039      3063877   248497  2018-02-11 00:29:26.000
# 2   4228130      3184893    50144  2016-06-14 00:30:08.000
# 3  22225624      6888562    70208  2018-09-03 14:37:19.000
# 4   4068771      2533490    67627  2016-05-21 11:51:02.000
#
#    Amount_Gross_Order city_name_fa  Quantity_item
# 0            597982.0   محمود آباد            1.0
# 1            980000.0       خرمدره            1.0
# 2            229358.0         قرچک            1.0
# 3             16514.0           قم            1.0
# 4            133028.0        تهران            1.0

# %%
df5['ID_Item'] = df5['id']

# %%
df5
# Out:
#            id                                   product_title_fa  \
# 0      723302            ماگ حرارتی لومانا مدل عرفانه کد MAG1042
# 1      727089       ست آبکش و آبگیر تیتیز مدل AP-9141 سایز متوسط
# 2      727096  روغن مرطوب کننده کدلی مدل Divine oil حجم 50 می...
# 3      727803  ست لحاف پوپلین هوبی مدل اما یکنفره چهار تکه کاوری
# 4      725222                         ماگ آبنبات رنگی مدل AR0143
# 5      723736                   شلوار مردانه ماسیمو دوتی کد 3221
# 6      724671                   کاپ قلم زنی گالری اسدی کد 151034
# 7      726009                             شانه مو دیهول مدل ترنج
# 8      725806                          پازل 1000 تکه مدل  K-2987
# 9      725822             لنز موبایل کلیپسی Telephoto مدل PR-112
# 10     724904     پولوشرت مردانه فرانکلین مارشال مدل پیوت کد 240
# 11     724686                تاپ زنانه لیدی مدل TANKTOP-SJ-GREEN
# 12     726175          عینک آفتابی بچگانه پلاریزه ونیز مدل S804
# ...

# %%
df3
# Out:
#         ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 0        2714054       469662    21386  2015-10-15 08:50:56.000
# 1       11104039      3063877   248497  2018-02-11 00:29:26.000
# 2        4228130      3184893    50144  2016-06-14 00:30:08.000
# 3       22225624      6888562    70208  2018-09-03 14:37:19.000
# 4        4068771      2533490    67627  2016-05-21 11:51:02.000
# 5       11479246      2841640   312932  2018-03-01 12:07:15.000
# 6        8267421      5235886    42365  2017-08-19 13:30:24.000
# 7       11588978      5574955   715680  2018-03-04 19:19:02.000
# 8        9916301      1145709   102588  2017-12-11 19:33:59.000
# 9       10740652      4928230   658519  2018-01-23 06:11:34.000
# 10       4605740       637880   138296  2016-08-02 10:48:18.000
# 11       5623610      2827566    23927  2016-12-04 03:12:59.000
# 12      13469523      3819595   564993  2018-06-13 12:28:55.000
# 13      24233238       500391  1707686  2018-11-21 07:44:36.000
# ...

# %%
df = pd.merge(df5, df3, on='ID_Item')

# %%
df
# Out:
#           id                                   product_title_fa  \
# 0     727974       قمقمه کودک طرح لیونل مسی ظرفیت 330 میلی لیتر
# 1     724597  تلویزیون ال ای دی هوشمند ال جی مدل 60SJ85000GI...
# 2     724597  تلویزیون ال ای دی هوشمند ال جی مدل 60SJ85000GI...
# 3     727826  تابلو فرش ماشینی نرمین کسا طرح کوهستان کد NKP....
# 4     724960                               کفش چرم دثار مدل ۶۶۶
# 5     724999                                گوشواره مدل رقص سما
# 6     724295               ماگ حرارتی لومانا مدل رضا کد MAG1052
# 7     724628          کاسه پایه دار قلمزنی گالری اسدی کد 151033
# 8     724102                     جلد کتاب استورم  طرح موان کد 3
# 9     726324                         عینک سه بعدی اپسون ELPGS03
# 10    727147                 دستبند دورپیچ گالری کیوسک مدل BW15
# 11    727147                 دستبند دورپیچ گالری کیوسک مدل BW15
# 12    723994                         کفش فوتسال مردانه مدل A103
# 13    727076  کاور آکام مدل AN80191 مناسب براي گوشی موبايل س...
# ...

# %%
grouped = df.groupby(['category_title_fa','brand_name_fa']).size().reset_index()

# %%
grouped
# Out:
#                                  category_title_fa  \
# 0                                          USB هاب
# 1     akhhvkhlnghdht3700ثغدشنساثدششقثدشئخیثمشب3700
# 2                                               dj
# 3                                     آبرنگ و گواش
# 4                                     آبرنگ و گواش
# 5                                     آبرنگ و گواش
# 6                                      آبمیوه گیری
# 7                                      آبمیوه گیری
# 8                                     آبکش و آبگیر
# 9                                     آبکش و آبگیر
# 10                                         آبگرمکن
# 11                                  آشنایی با فنون
# 12                                  آفتابگیر خودرو
# 13                                  آفتابگیر خودرو
# 14                                    آموزش موسیقی
# 15                      آموزش نرم‌افزار و کامپیوتر
# 16                 آموزش، سرگرمی و اکسسوری حیوانات
# ...

# %%
grouped.columns
# Out:
# Index(['category_title_fa', 'brand_name_fa', 0], dtype='object')

# %%
grouped.sort_values(by=[0, 'brand_name_fa'], ascending=False)
# Out:
#               category_title_fa  brand_name_fa    0
# 1551            کیف و کاور گوشی         متفرقه  185
# 314     تی‌شرت و پولوشرت مردانه         متفرقه  164
# 1231                       پرده         متفرقه  152
# 199                  تابلو شاسی         متفرقه  100
# 591           سایر لوازم تزئینی         متفرقه   97
# 1098      محافظ صفحه نمایش گوشی         متفرقه   94
# 60                 ابزار مهمانی         متفرقه   91
# 845                 عینک آفتابی         متفرقه   87
# 309     تی‌شرت و پولوشرت مردانه        رادیکال   77
# 465                        دفتر         متفرقه   68
# 1378                  کتاب چاپی        دبستانک   64
# 1540            کیف و کاور گوشی            آکو   59
# 560           ساعت مچی عقربه‌ای         متفرقه   51
# 1602                    گردنبند         متفرقه   51
# 696                 شال و روسری         متفرقه   50
# 895   قطعات جانبی موبایل و تبلت          ماهوت   49
# 188                       تابلو         متفرقه   48
# ...
