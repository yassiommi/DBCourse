# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('1.csv')

# %%
df1.head()
# Out:
#          id  product_variant_id  selling_price  rrp_price base_price  \
# 0  18752043             1977385         850000     850000         \N
# 1  18752022             1977380       12550000   12550000         \N
# 2  18752046             1977380       12500000   12500000         \N
# 3  18751982             1977374         310000     310000         \N
# 4  18752018             1977374         300000     300000         \N
#
#   buy_price  order_limit start_at end_at tags  show_in_price_history  active  \
# 0        \N            1       \N     \N   \N                      1       1
# 1        \N            2       \N     \N   \N                      1       0
# 2        \N            2       \N     \N   \N                      1       1
# 3        \N            2       \N     \N   \N                      1       0
# 4        \N            2       \N     \N   \N                      1       1
#
#             created_at  product_id  marketplace_seller_id
# ...

# %%
! pip install xlrd
# Out:
# ...
#     100% |████████████████████████████████| 112kB 191kB/s ta 0:00:01
# ...
# You are using pip version 19.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
df2 = pd.read_excel('2.xlsx')

# %%
df2.head()
# Out:
#    product_id                                      product_title title_en  \
# 0        3692                        ماوس بی‌سیم لاجیتک مدل M325       IT
# 1       90213  شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...       AC
# 2       59473              یدک پولیشر میکروفایبر مهسان مدل 20119       HW
# 3      120499   گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم‌کارت       MO
# 4       67200  شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپ...       AC
#
#    user_id  likes  dislikes verification_status        recommend  \
# 0   989472      0         0            verified               \N
# 1  3862150      4         1            verified      recommended
# 2   626843      1         0            verified  not_recommended
# 3   786887      6        11            verified          no_idea
# 4   854531     19         4            verified          no_idea
#
#                                  title  \
# 0                                  NaN
# 1                         واقعاً عالیه
# ...

# %%
df3 = pd.read_csv('3.csv')

# %%
df3.head()
# Out:
#    ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 0   2714054       469662    21386  2015-10-15 08:50:56.000
# 1  11104039      3063877   248497  2018-02-11 00:29:26.000
# 2   4228130      3184893    50144  2016-06-14 00:30:08.000
# 3  22225624      6888562    70208  2018-09-03 14:37:19.000
# 4   4068771      2533490    67627  2016-05-21 11:51:02.000
#
#    Amount_Gross_Order city_name_fa  Quantity_item
# 0            597982.0   محمود آباد            1.0
# 1            980000.0       خرمدره            1.0
# 2            229358.0         قرچک            1.0
# 3             16514.0           قم            1.0
# 4            133028.0        تهران            1.0

# %%
df4 = pd.read_excel('4.xlsx')

# %%
df4.head()
# Out:
#    product_id         confirmed_at  \
# 0       90213  2018-08-23 11:05:47
# 1       56871  2018-08-23 10:21:53
# 2       49738  2018-10-13 11:13:39
# 3      134367  2018-10-17 11:27:57
# 4      151402  2018-08-23 10:28:47
#
#                                              comment
# 0  سلام، قبل اینکه نظرم رو بگم میخواستم به یک موض...
# 1  بوی تند ولی خوشبو داره.ماندگاریش خوبه و هر چقد...
# 2  متاسفانه عمر مفید این ماشین کم هست و بعد از دو...
# 3  افا از وقتی من اینو واسه پسرم خریدم همه بچه ها...
# 4  این تیغ محصول کشور آمریکا هست ( در عکس محصول م...

# %%
len(df4)
# Out:
# 100008

# %%
df5 = pd.read_excel('5.xlsx')

# %%
df5.head()
# Out:
#        id                                   product_title_fa  \
# 0  723302            ماگ حرارتی لومانا مدل عرفانه کد MAG1042
# 1  727089       ست آبکش و آبگیر تیتیز مدل AP-9141 سایز متوسط
# 2  727096  روغن مرطوب کننده کدلی مدل Divine oil حجم 50 می...
# 3  727803  ست لحاف پوپلین هوبی مدل اما یکنفره چهار تکه کاوری
# 4  725222                         ماگ آبنبات رنگی مدل AR0143
#
#                          product_title_en  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3  Hobby Emma Quilt Single Set - 4 Pieces
# 4                                     NaN
#
#                                             url_code  \
# 0            ماگ-حرارتی-لومانا-مدل-عرفانه-کد-mag1042
# 1       ست-آبکش-و-آبگیر-تیتیز-مدل-ap-9141-سایز-متوسط
# 2  روغن-مرطوب-کننده-کدلی-مدل-divine-oil-حجم-50-می...
# 3  ست-لحاف-پوپلین-هوبی-مدل-اما-یکنفره-چهار-تکه-کاوری
# 4                         ماگ-آبنبات-رنگی-مدل-ar0143
#
# ...

# %%
df5['product_id'] = df5['id']

# %%
df5['product_title'] = df5['product_title_fa']

# %%
df5.head()
# Out:
#        id                                   product_title_fa  \
# 0  723302            ماگ حرارتی لومانا مدل عرفانه کد MAG1042
# 1  727089       ست آبکش و آبگیر تیتیز مدل AP-9141 سایز متوسط
# 2  727096  روغن مرطوب کننده کدلی مدل Divine oil حجم 50 می...
# 3  727803  ست لحاف پوپلین هوبی مدل اما یکنفره چهار تکه کاوری
# 4  725222                         ماگ آبنبات رنگی مدل AR0143
#
#                          product_title_en  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3  Hobby Emma Quilt Single Set - 4 Pieces
# 4                                     NaN
#
#                                             url_code  \
# 0            ماگ-حرارتی-لومانا-مدل-عرفانه-کد-mag1042
# 1       ست-آبکش-و-آبگیر-تیتیز-مدل-ap-9141-سایز-متوسط
# 2  روغن-مرطوب-کننده-کدلی-مدل-divine-oil-حجم-50-می...
# 3  ست-لحاف-پوپلین-هوبی-مدل-اما-یکنفره-چهار-تکه-کاوری
# 4                         ماگ-آبنبات-رنگی-مدل-ar0143
#
# ...

# %%
# کدام دسته از محصولات بیشترین نظرات را دارند؟ در بین نظرات این دسته‌ چقدر نظرات تکراری و یا خیلی شبیه به هم با اختلاف دو یا سه کلمه وجود دارد؟

# %%
comments = pd.merge(df2, df4, on=['product_id', 'comment'])

# %%
comments.head()
# Out:
#    product_id                                      product_title title_en  \
# 0       56871  ادو پرفیوم زنانه امپر مدل Chifon حجم 100 میلی ...       PC
# 1       49738               ماشین اصلاح صورت رمینگتون مدل MB4555       PA
# 2      134367                    ماشین بازی بیبی لند مدل Top Car       TS
# 3      151402        خودتراش سیلور مدل M5 Magnum به همراه یک یدک       PC
# 4       26368                                 ماساژور بیورر MG80       PA
#
#    user_id  likes  dislikes verification_status    recommend  \
# 0  1139954      2         2            verified           \N
# 1  2764879      2         1            verified           \N
# 2  3015544     10         5            verified  recommended
# 3  1223376      2         6            verified           \N
# 4  1309402      5         0            verified           \N
#
#                            title  \
# 0                         عطر...
# 1                 عمر مفید کوتاه
# 2               لطفا موجودش کنید
# ...

# %%
comments = comments.merge(df5, on='product_title')

# %%
comments.head()
# Out:
#    product_id_x                        product_title title_en  user_id  likes  \
# 0         97242         کتاب اثر مرکب اثر دارن هاردی       MA  4200607      6
# 1        139943   قفل فرمان خودرو رونیکس مدل RH-4240       TC  1161457      2
# 2        180451  مچ بند هوشمند شیائومی مدل Mi Band 2       PA  4294800      3
# 3        180451  مچ بند هوشمند شیائومی مدل Mi Band 2       PA  4294800      3
# 4        180451  مچ بند هوشمند شیائومی مدل Mi Band 2       PA  4867696      4
#
#    dislikes verification_status    recommend  \
# 0         1            verified           \N
# 1         0            verified  recommended
# 2         1            verified  recommended
# 3         1            verified  recommended
# 4         1            verified  recommended
#
#                                   title  \
# 0  کتابی که در زندگی من تغییر ایجاد کرد
# 1                            بسیار عالی
# 2                                عالییی
# 3                                عالییی
# ...

# %%
cats = comments['category_title_fa'].unique()
print(cats)
# Out:
# ['کتاب چاپی' 'قفل فرمان و پدال و زاپاس' 'مچ بند هوشمند' 'کنسول خانگی']

# %%
catskey = comments['category_keywords'].unique()
print(catskey)
# Out:
# ['کتاب چاپی Book'
#  'قفل فرمان و پدال و زاپاس streeing-pedal-sapre-tire-lock'
#  'مچ بند هوشمند SmartBand' 'کنسول خانگی Station-Gaming-Consoles']

# %%
books = comments[comments['category_title_fa'] == 'کتاب چاپی']
pedal_felan = comments[comments['category_title_fa'] == 'قفل فرمان و پدال و زاپاس']
smartband = comments[comments['category_title_fa'] == 'مچ بند هوشمند']
consoles = comments[comments['category_title_fa'] == 'کنسول خانگی']

# %%
books.head()
# Out:
#     product_id_x                       product_title title_en  user_id  likes  \
# 0          97242        کتاب اثر مرکب اثر دارن هاردی       MA  4200607      6
# 24        575022  کتاب زنان کوچک اثر لوییزا می الکات       MA  7161547      1
#
#     dislikes verification_status    recommend  \
# 0          1            verified           \N
# 24         0            verified  recommended
#
#                                    title  \
# 0   کتابی که در زندگی من تغییر ایجاد کرد
# 24                           حتما بخونید
#
#                                               comment     ...       \
# 0   این کتاب راهکارهایی پیش روی ما میگذارد که تاثی...     ...
# 24                                         بسیار عالی     ...
#
#                       product_title_fa product_title_en  \
# 0         کتاب اثر مرکب اثر دارن هاردی              NaN
# 24  کتاب زنان کوچک اثر لوییزا می الکات                /
#
#                               url_code  \
# 0         کتاب-اثر-مرکب-اثر-دارن-هاردی
# ...

# %%
len(books)
# Out:
# 2

# %%
len(pedal_felan)
# Out:
# 1

# %%
len(smartband)
# Out:
# 20

# %%
len(consoles)
# Out:
# 2

# %%
new_try = pd.merge(df5, df2, on='product_id')

# %%
len(new_try)
# Out:
# 9554

# %%
new_try.head()
# Out:
#        id                                   product_title_fa  \
# 0  723227  اسپری ضد سوختگی ساووی مدل Antiseptic حجم 50 می...
# 1  725786                   ساعت مچی عقربه ای زنانه مدل 7672
# 2  725253                     کیف کارت چرم تهران کیف مدل J44
# 3  727088    روبالشی صرمه طرح اصفهان مدل R-es112 بسته 2 عددی
# 4  727088    روبالشی صرمه طرح اصفهان مدل R-es112 بسته 2 عددی
#
#                product_title_en  \
# 0  Savoy Burn Relief Spray 50ml
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                                             url_code  \
# 0  اسپری-ضد-سوختگی-ساووی-مدل-antiseptic-حجم-50-می...
# 1                   ساعت-مچی-عقربه-ای-زنانه-مدل-7672
# 2                     کیف-کارت-چرم-تهران-کیف-مدل-j44
# 3    روبالشی-صرمه-طرح-اصفهان-مدل-r-es112-بسته-2-عددی
# 4    روبالشی-صرمه-طرح-اصفهان-مدل-r-es112-بسته-2-عددی
#
# ...

# %%
new_cat = new_try['category_keywords'].unique()
print(new_cat)
# Out:
# ['کرم و ژل ترمیم کننده Repair-Cream'
#  'ساعت مچی عقربه\u200cای  Analogue-Watch' 'کیف پول Wallets'
#  'رو بالشی PillowsCover' 'مایو -Swimsuits' 'کیف و کوله مدرسه Bags'
#  'ماگ، لیوان و فنجان CupandMug'
#  'تاپ، تونیک و سارافون زنانه womens-tops-tunics' 'کفش زنانه Women-Shoes'
#  'دمپایی Slippers' 'استیکر و تابلو کودک و نوزاد Sticker'
#  'شورت زنانه Women-UW-Brief' 'ابزار شوخی  Humor-Toy'
#  'کفش ورزشی مردانه Men-Sport-Shoes' 'خط کش Ruler'
#  'کیف و کوله پشتی چرم Bag-Backpack' 'سینی Tray'
#  'شوینده ظروف Dishes-Detergents'
#  'ابزارهای اندازه گیری دیجیتالی و لیزری Distance-Measurer'
#  'تجهیزات نظم دهنده داخل خودرو Car-Organizer-Equipment'
#  'شال و روسری shawls-scarves' 'گل و گلدان Flower-Pot'
#  'ابزار مهمانی Party-Tools' 'زیر انداز Mat' 'جاروبرقی Vaccum-Cleaner'
#  'پاپیون و کراوات TieandBowTie' 'حشره کش و سوسک کش Insecticide'
#  'بارفیکس PullUp' 'ماسک صورت Face-Masque' 'لامپ خودرو Car-Lamp'
#  'کاغذ Paper' 'چراغ خواب کودک و نوزاد Baby-Decorative-Lamp'
# ...

# %%
dict = {}
for i in range(len(new_cat)):
    dict[new_cat[i]] = len(new_try[new_try['category_keywords'] == new_cat[i]])

# %%
dict
# Out:
# {'کرم و ژل ترمیم کننده Repair-Cream': 5,
#  'ساعت مچی عقربه\u200cای  Analogue-Watch': 137,
#  'کیف پول Wallets': 123,
#  'رو بالشی PillowsCover': 24,
#  'مایو -Swimsuits': 6,
#  'کیف و کوله مدرسه Bags': 138,
#  'ماگ، لیوان و فنجان CupandMug': 23,
#  'تاپ، تونیک و سارافون زنانه womens-tops-tunics': 17,
#  'کفش زنانه Women-Shoes': 67,
#  'دمپایی Slippers': 8,
#  'استیکر و تابلو کودک و نوزاد Sticker': 10,
#  'شورت زنانه Women-UW-Brief': 11,
#  'ابزار شوخی  Humor-Toy': 25,
#  'کفش ورزشی مردانه Men-Sport-Shoes': 270,
#  'خط کش Ruler': 7,
#  'کیف و کوله پشتی چرم Bag-Backpack': 228,
#  'سینی Tray': 18,
#  'شوینده ظروف Dishes-Detergents': 14,
#  'ابزارهای اندازه گیری دیجیتالی و لیزری Distance-Measurer': 5,
#  'تجهیزات نظم دهنده داخل خودرو Car-Organizer-Equipment': 5,
#  'شال و روسری shawls-scarves': 44,
#  'گل و گلدان Flower-Pot': 14,
#  'ابزار مهمانی Party-Tools': 14,
#  'زیر انداز Mat': 22,
#  'جاروبرقی Vaccum-Cleaner': 18,
#  'پاپیون و کراوات TieandBowTie': 8,
# ...

# %%
nann = new_try[new_try['comment'] == 'NaN']

# %%
nann.head()
# Out:
# Empty DataFrame
# Columns: [id, product_title_fa, product_title_en, url_code, title_alt, category_title_fa, category_keywords, brand_name_fa, brand_name_en, product_attributes, product_id, product_title_x, product_title_y, title_en, user_id, likes, dislikes, verification_status, recommend, title, comment, advantages, disadvantages]
# Index: []
#
# [0 rows x 23 columns]

# %%
import operator
sorted_cm = sorted(dict.items(), key=operator.itemgetter(1))

# %%
sorted_cm
# Out:
# [(nan, 0),
#  ('چراغ خواب کودک و نوزاد Baby-Decorative-Lamp', 1),
#  ('سنگ نما و کاشی Stone-Wall', 1),
#  ('رم لپ تاپ Laptop-RAM', 1),
#  ('واکس Wax', 1),
#  ('صندوق Safe', 1),
#  ('چادر عکاسی  Light-Tent', 1),
#  ('پنل خورشیدی Solar-Panel', 1),
#  ('سمپاش Sprayer', 1),
#  ('روکش صندلی خودرو Car-Chair-Covers', 1),
#  ('ماسک Mask', 1),
#  ('قهوه ساز Coffee-Makers', 1),
#  ('تجهیزات کارگاهی Workshop-Equipment', 1),
#  ('قفل Lock', 1),
#  ('پد امضا Signature-Pad', 1),
#  ('ضبط کننده صدا  IC-Rcorder', 1),
#  ('میکروسکوپ Microscope', 1),
#  ('رژ لب مدادی Lipstick-Pen', 1),
#  ('پوشک بزرگسال Adult-Protective-Diaper', 1),
#  ('شعله افکن Torch', 1),
#  ('اجاق گاز Oven', 1),
#  ('پینگ پنگ Pingpong', 1),
#  ('آسیاب نمک و فلفل PepperGrinder', 1),
#  ('زیر قابلمه\u200cای و زیربشقابی PanMate', 1),
#  ('لوازم جانبی نور و روشنایی Light-Accessories', 1),
#  ('شارژر مخصوص لپ تاپ Laptop-Charger', 1),
#  ('آنتن تقویتی Antenna', 1),
#  ('گبه Gabbeh', 1),
#  ('آویز ساعت طلا Watch-Pendent-Gold', 1),
# ...

# %%
# کفش ورزشی مردانه، کیف و کوله‌پشتی چرم، محافظ صفحه نمایش گوشی و کیف و ماور گوشی به ترتیب بیش‌ترین کامنت‌ها رو دارن

# %%
#چه کلماتی در نظرات بیشتر از همه ظاهر شده‌اند؟

# %%
# !pip install wordcloud
# Out:
# ...
#     100% |████████████████████████████████| 163kB 230kB/s ta 0:00:01
# ...
# You are using pip version 19.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
df4.to_csv('/commenttext.txt', columns=df4['comment'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-44be29bd084c> in <module>
# ----> 1 df4.to_csv('/commenttext.txt', columns=df4['comment'])
#
# NameError: name 'df4' is not defined

# %%
commentss = df4['comment']

# %%
commentss.to_csv('cms.txt', index=False)

# %%
from wordcloud import WordCloud
text = open("cms.txt", encoding="utf-8").read()

# %%
wordcloud = WordCloud().generate(text)

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
! pip install persian_wordcloud
# Out:
# ...
#     100% |████████████████████████████████| 71kB 357kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 829kB 1.1MB/s ta 0:00:01
# ...
#   Stored in directory: /Users/Yassi/Library/Caches/pip/wheels/d6/cb/3e/9cbd2b569d53b1442208fa3a4c66c2fc2bd6ade54231d08549
# ...
#   Stored in directory: /Users/Yassi/Library/Caches/pip/wheels/0c/61/d2/d6b7317325828fbb39ee6ad559dbe4664d0896da4721bf379e
# Successfully built persian-wordcloud future
# ...
# You are using pip version 19.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from persian_wordcloud.wordcloud import PersianWordCloud
wordcloud = PersianWordCloud(only_persian=True).generate(text)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-24-ba13026e6eb1> in <module>
#       1 from persian_wordcloud.wordcloud import PersianWordCloud
# ----> 2 wordcloud = PersianWordCloud(only_persian=True).generate(text)
#
# /usr/local/lib/python3.7/site-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     142         """
#     143         # reshape persian words
# --> 144         text = get_display(arabic_reshaper.reshape(text))
#     145         return self.generate_from_text(text)
#     146
#
# /usr/local/lib/python3.7/site-packages/bidi/algorithm.py in get_display(unicode_or_str, encoding, upper_is_rtl, base_dir, debug)
#     646     resolve_weak_types(storage, debug)
#     647     resolve_neutral_types(storage, debug)
# --> 648     resolve_implicit_levels(storage, debug)
#     649     reorder_resolved_levels(storage, debug)
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
#سحرخیز‌ترین و شب‌زنده‌دارترین شهر‌ها بر اساس اطلاعات خرید مشتریان کدام شهرها هستند؟ میزان سحرخیزی یا شب‌زنده‌داری با مقدار خرید رابطه‌ای دارد؟

# %%
df3.head()
# Out:
#    ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 0   2714054       469662    21386  2015-10-15 08:50:56.000
# 1  11104039      3063877   248497  2018-02-11 00:29:26.000
# 2   4228130      3184893    50144  2016-06-14 00:30:08.000
# 3  22225624      6888562    70208  2018-09-03 14:37:19.000
# 4   4068771      2533490    67627  2016-05-21 11:51:02.000
#
#    Amount_Gross_Order city_name_fa  Quantity_item        date
# 0            597982.0   محمود آباد            1.0  2015-10-15
# 1            980000.0       خرمدره            1.0  2018-02-11
# 2            229358.0         قرچک            1.0  2016-06-14
# 3             16514.0           قم            1.0  2018-09-03
# 4            133028.0        تهران            1.0  2016-05-21

# %%
df3['date'], df3['time'] = zip(*df3['DateTime_CartFinalize'].map(lambda x: x.split(' ')))

# %%
df3.head()
# Out:
#    ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 0   2714054       469662    21386  2015-10-15 08:50:56.000
# 1  11104039      3063877   248497  2018-02-11 00:29:26.000
# 2   4228130      3184893    50144  2016-06-14 00:30:08.000
# 3  22225624      6888562    70208  2018-09-03 14:37:19.000
# 4   4068771      2533490    67627  2016-05-21 11:51:02.000
#
#    Amount_Gross_Order city_name_fa  Quantity_item        date          time
# 0            597982.0   محمود آباد            1.0  2015-10-15  08:50:56.000
# 1            980000.0       خرمدره            1.0  2018-02-11  00:29:26.000
# 2            229358.0         قرچک            1.0  2016-06-14  00:30:08.000
# 3             16514.0           قم            1.0  2018-09-03  14:37:19.000
# 4            133028.0        تهران            1.0  2016-05-21  11:51:02.000

# %%
print(df3['time'].unique())
# Out:
# ['08:50:56.000' '00:29:26.000' '00:30:08.000' ... '01:49:29.000'
#  '05:05:39.000' '23:47:06.000']

# %%
saharkhiz = df3[(df3['time']>='03:00:00.000') & (df3['time']<='06:00:00.000')]

# %%
saharkhiz.head()
# Out:
#     ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 11   5623610      2827566    23927  2016-12-04 03:12:59.000
# 20   6156363      3549803   193926  2017-01-24 03:05:35.000
# 23   9194454      1468632    67518  2017-10-28 03:52:34.000
# 24  22454972      3527897   882178  2018-09-11 04:53:56.000
# 92  12082993       834004   438498  2018-03-28 03:15:17.000
#
#     Amount_Gross_Order city_name_fa  Quantity_item        date          time
# 11            108000.0         لالی            1.0  2016-12-04  03:12:59.000
# 20             41284.0        تهران            3.0  2017-01-24  03:05:35.000
# 23             71560.0           قم            1.0  2017-10-28  03:52:34.000
# 24             47706.0        تهران            1.0  2018-09-11  04:53:56.000
# 92            122936.0        تهران            1.0  2018-03-28  03:15:17.000

# %%
cities = saharkhiz['city_name_fa'].unique()
dict2 = {}
for i in range(len(cities)):
    dict2[cities[i]] = len(saharkhiz[saharkhiz['city_name_fa'] == cities[i]])

# %%
import operator
sorted_cities_sahar = sorted(dict2.items(), key=operator.itemgetter(1))
print(sorted_cities_sahar)
# Out:
# [('لالی', 1), ('کلارآباد', 1), ('دماوند', 1), ('دهدز', 1), ('رودهن', 1), ('زارچ', 1), ('آباده', 1), ('شلمزار', 1), ('دهلران', 1), ('ازنا', 1), ('محلات', 1), ('فلاورجان', 1), ('نقده', 1), ('حاجی آباد', 1), ('چمران', 1), ('میمه', 1), ('باغستان', 1), ('کمال شهر', 1), ('مرودشت', 1), ('وزوان', 1), ('گلستان', 1), ('خان ببین', 1), ('بوئین زهرا', 1), ('ایمانشهر', 1), ('رستم آباد', 1), ('دلوار', 1), ('خمیر', 1), ('پاوه', 1), ('بندر جاسک', 1), ('اهر', 1), ('زاویه', 1), ('قروه', 1), ('نکا', 1), ('شهر جدید مهاجران', 1), ('چمستان', 1), ('سرخه', 1), ('سوسنگرد', 1), ('جاورسیان', 1), ('هچیرود', 1), ('طبس', 1), ('کنگاور', 1), ('سراب', 1), ('خور', 1), ('هفشجان', 1), ('درگز', 1), ('بیستون', 1), ('رویدر', 1), ('املش', 1), ('زرین شهر', 1), ('برازجان', 1), ('مینودشت', 1), ('فیروزآباد', 1), ('اشکذر', 1), ('دره شهر', 1), ('قائن', 1), ('چابکسر', 1), ('سراوان', 1), ('عماد ده', 1), ('چهاردانگه', 1), ('بردسیر', 1), ('خوراسگان', 1), ('الوند', 1), ('شازند', 1), ('مبارکه', 1), ('خرمدشت', 1), ('بروجن', 1), ('سیاهکل
# ...

# %%
# سحرخیزترین شهرها به ترتیب می‌شن: تهران - اهواز - مشهد - اصفهان - کرج - شیراز

# %%
shabfelan = df3[(df3['time']>='00:00:00.000') & (df3['time']<='03:00:00.000')]

# %%
shabfelan.head()
# Out:
#     ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 1   11104039      3063877   248497  2018-02-11 00:29:26.000
# 2    4228130      3184893    50144  2016-06-14 00:30:08.000
# 21  11140715      6500201   574889  2018-02-13 02:15:42.000
# 22   9503051      3048383   449799  2017-11-18 01:05:08.000
# 32  23241056       535856  1399641  2018-10-13 00:18:22.000
#
#     Amount_Gross_Order city_name_fa  Quantity_item        date          time
# 1             980000.0       خرمدره            1.0  2018-02-11  00:29:26.000
# 2             229358.0         قرچک            1.0  2016-06-14  00:30:08.000
# 21            380000.0        اهواز            1.0  2018-02-13  02:15:42.000
# 22             20000.0       اصفهان            1.0  2017-11-18  01:05:08.000
# 32             55000.0         ساری            1.0  2018-10-13  00:18:22.000

# %%
cities2 = shabfelan['city_name_fa'].unique()
dict3 = {}
for i in range(len(cities)):
    dict3[cities2[i]] = len(shabfelan[shabfelan['city_name_fa'] == cities2[i]])

# %%
sorted_cities_shab = sorted(dict3.items(), key=operator.itemgetter(1))
print(sorted_cities_shab)
# Out:
# [('قمصر', 1), ('زاویه', 1), ('جعفر آباد', 1), ('کمیجان', 1), ('فیروزآباد', 1), ('طاقانک', 1), ('فیروزان', 1), ('بیارجمند', 1), ('چاف و چمخاله', 1), ('رامیان', 1), ('موسیان', 1), ('سیه چشمه', 1), ('ابوموسی', 1), ('ساروق', 1), ('قصر قند', 1), ('مهر', 1), ('پلدشت', 1), ('نوسود', 1), ('خنداب', 2), ('تودشک', 2), ('توحید', 2), ('شاندیز', 2), ('گالیکش', 2), ('هفشجان', 2), ('باقرشهر', 2), ('رحیم آباد', 2), ('آستانه', 2), ('گندمان', 2), ('فراشبند', 2), ('طرقبه', 2), ('بنت', 2), ('آذرشهر', 2), ('کلاردشت', 2), ('شاهدشهر', 2), ('آبش احمد', 2), ('باغستان', 2), ('درق', 2), ('سرخس', 2), ('سنگر', 2), ('رویدر', 3), ('درگهان', 3), ('سردرود', 3), ('خاش', 3), ('بسطام', 3), ('ابرکوه', 3), ('تایباد', 3), ('گلشهر', 3), ('دهاقان', 3), ('صائین قلعه', 3), ('سامان', 3), ('قروه در جزین', 3), ('سربیشه', 3), ('ازنا', 3), ('شیرود', 3), ('تیران', 3), ('شفت', 3), ('آشخانه', 3), ('کهنوج', 4), ('خورزوق', 4), ('زرند', 4), ('مهران', 4), ('رستم آباد', 4), ('ایزد شهر', 4), ('بافت', 4), ('صفا شهر', 4), ('صفادشت', 4), ('تکا
# ...

# %%
# شب‌زنده‌دارترین شهرها می‌شن: تهران - مشهد - اصفهان - کرج - اهواز - شیراز - رشت - تبریز

# %%
# میزان فروش در جشنواره‌‌های سال نو، یلدا و ... چه تفاوتی با بقیه روزها دارد؟
# new year = 20 march 
# yalda = 20, 21 dec

# %%
df3.head()
# Out:
#    ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 0   2714054       469662    21386  2015-10-15 08:50:56.000
# 1  11104039      3063877   248497  2018-02-11 00:29:26.000
# 2   4228130      3184893    50144  2016-06-14 00:30:08.000
# 3  22225624      6888562    70208  2018-09-03 14:37:19.000
# 4   4068771      2533490    67627  2016-05-21 11:51:02.000
#
#    Amount_Gross_Order city_name_fa  Quantity_item        date          time  \
# 0            597982.0   محمود آباد            1.0  2015-10-15  08:50:56.000
# 1            980000.0       خرمدره            1.0  2018-02-11  00:29:26.000
# 2            229358.0         قرچک            1.0  2016-06-14  00:30:08.000
# 3             16514.0           قم            1.0  2018-09-03  14:37:19.000
# 4            133028.0        تهران            1.0  2016-05-21  11:51:02.000
#
#    year month day
# 0  2015    10  15
# 1  2018    02  11
# 2  2016    06  14
# 3  2018    09  03
# 4  2016    05  21

# %%
df3['year'], df3['month'], df3['day'] = zip(*df3['date'].map(lambda x: x.split('-')))

# %%
yalda = df3[df3['date'].str.contains("-12-21") | (df3['date'].str.contains("-12-20"))]

# %%
yalda.head()
# Out:
#      ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 60   10095770      5708387   436778  2017-12-20 01:27:47.000
# 78   10096664      2343976   102508  2017-12-20 01:06:45.000
# 95   10179164      1476510   174490  2017-12-21 02:11:06.000
# 118   5774506      4475159   234956  2016-12-20 09:23:13.000
# 126  10172243      5534482   554236  2017-12-21 01:19:25.000
#
#      Amount_Gross_Order city_name_fa  Quantity_item        date          time  \
# 60             900000.0        تهران            1.0  2017-12-20  01:27:47.000
# 78              25046.0        تهران           10.0  2017-12-20  01:06:45.000
# 95             197523.0        تهران            2.0  2017-12-21  02:11:06.000
# 118          27055046.0        تهران            1.0  2016-12-20  09:23:13.000
# 126            850000.0         زابل            1.0  2017-12-21  01:19:25.000
#
#      year month day
# 60   2017    12  20
# 78   2017    12  20
# 95   2017    12  21
# 118  2016    12  20
# 126  2017    12  21

# %%
yalda['Amount_Gross_Order'].sum()
# Out:
# 3943849394.0

# %%
newyear = df3[df3['date'].str.contains("-03-20")]

# %%
newyear.head()
# Out:
#       ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 2111  11986823       844337   760467  2018-03-20 11:57:44.000
# 5998   1896644      2347413    20017  2015-03-20 13:25:04.000
# 6754  11990634      3471617    59164  2018-03-20 20:53:02.000
# 7808   3677170      3175710    93067  2016-03-20 12:23:11.000
# 7826   1180995       931498    14601  2014-03-20 10:39:39.000
#
#       Amount_Gross_Order  city_name_fa  Quantity_item        date  \
# 2111            290000.0         تهران            1.0  2018-03-20
# 5998           2398148.0          ساری            1.0  2015-03-20
# 6754            359450.0         تهران            1.0  2018-03-20
# 7808              9174.0         تهران            4.0  2016-03-20
# 7826            840000.0  آران و بیدگل            1.0  2014-03-20
#
#               time  year month day
# 2111  11:57:44.000  2018    03  20
# 5998  13:25:04.000  2015    03  20
# 6754  20:53:02.000  2018    03  20
# 7808  12:23:11.000  2016    03  20
# ...

# %%
newyear['Amount_Gross_Order'].sum()
# Out:
# 297510057.0

# %%
import matplotlib.pyplot as plt
normalday = df3[df3['date'].str.contains("-09-12")]

# %%
normalday['Amount_Gross_Order'].sum()
# Out:
# 679032464.0
